# %%
# %pip install -q tavily-python deepagents

# %%
os.environ["OPENAI_API_KEY"] = ""
os.environ["TAVILY_API_KEY"] = ""
os.environ["LANGSMITH_API_KEY"] = ""
os.environ["LANGSMITH_TRACING"] = "true"

# %%
import os
from typing import Literal
from tavily import TavilyClient
from deepagents import create_deep_agent

tavily_client = TavilyClient(api_key=os.environ["TAVILY_API_KEY"])

def internet_search(
    query: str,
    max_results: int = 5,
    topic: Literal["general", "news", "finance"] = "general",
    include_raw_content: bool = False,
):
    """Run a web search"""
    return tavily_client.search(
        query,
        max_results=max_results,
        include_raw_content=include_raw_content,
        topic=topic,
    )

# %%
# System prompt to steer the agent to be an expert researcher
research_instructions = """You are an expert researcher. Your job is to conduct thorough research and then write a polished report.

You have access to an internet search tool as your primary means of gathering information.

## `internet_search`

Use this to run an internet search for a given query. You can specify the max number of results to return, the topic, and whether raw content should be included.
"""

# %%
agent = create_deep_agent(
    model="openai:gpt-4.1",
    tools=[internet_search],
    system_prompt=research_instructions,
)

# %%
result = agent.invoke({"messages": [{"role": "user", "content": "What is langgraph?"}]})

# Print the agent's response
print(result["messages"][-1].content)
# Out:
# [{'type': 'text', 'text': '**Langgraph** is a Python framework for building stateful, multi-agent applications using graphs. It\'s built on top of LangChain, which is a popular framework for developing applications powered by language models. Langgraph helps you structure workflows in the form of a graph, where nodes represent steps or agents and edges represent transitions between those steps.\n\n### Key Features\n- **Graph-based workflow:** Design complex flows as explicitly connected states, allowing for iterative, branching, and multi-agent scenarios.\n- **Stateful execution:** Maintains context throughout the workflow, suitable for tasks too sophisticated for simple chains or pipelines.\n- **Multi-agent support:** Integrates multiple LLM agents, tools, and humans in single or parallel flows.\n- **Flexible integration:** Works seamlessly with LangChain tools, prompts, and agents.\n\n### Use Cases\n- Conversational agents with memory and decision trees.\n- Automated research assistants that branch into subtasks.\n- Complex document analysis pipelines.\n- Multi-agent negotiation or planning systems.\n\n### Example\nHere’s a brief code snippet to showcase constructing a workflow with Langgraph:\n\n```python\nimport langgraph\n\n# Define nodes (steps)\ndef node_a(state): ...\ndef node_b(state): ...\n\n# Build graph\ng = langgraph.Graph()\ng.add_node("A", node_a)\ng.add_node("B", node_b)\ng.add_edge("A", "B")\ng.add_edge("B", "A")  # Loops are possible\n\nrunner = g.compile()\nrunner.run(input_data)\n```\n\n### Summary\n**Langgraph** is for developers who want to go beyond simple LLM chains and need fine control over state propagation, multi-step workflows, and agent collaboration—with reusable, visually representable graphs. It is especially useful for complex production AI applications.\n\nFor more info, visit the [Langgraph GitHub repository](https://github.com/langchain-ai/langgraph) or check out [LangGraph documentation](https://langchain-ai.github.io/langgraph/).', 'annotations': [], 'id': 'msg_060a519ffda892f60069e0017c15288197b21c832da7e559f5'}]
